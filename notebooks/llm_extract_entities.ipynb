# %%
import sys
import os

# Adiciona o diretório raiz do projeto ao sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.agents.tools.extract_parameters import extract_parameters_tool
# Out:
# 2025-07-08 17:57:17.237 | INFO     | src.config:<module>:13 - PROJ_ROOT path is: C:\Ana\Pessoal\TCC\tcc_ufg_akcit_nlp

# %%
perguntas = [
    "Qual o estoque de loratadina em Campanário, MG?",
    "Tem dipirona em Goiânia, GO?",
    "Preciso saber o estoque de ibuprofeno em São Paulo, SP",
    "Qual o estoque de nimesulida em Recife, PE?"
]

for pergunta in perguntas:
    resultado = extract_parameters_tool(pergunta)
    print(f'Pergunta: {pergunta}')
    print('Resultado extraído:', resultado)
    print('-' * 60)
# Out:
# Resposta do LLM: ```json
# {
#   "medicine": "loratadina",
#   "city_name": "Campanário",
#   "uf": "MG"
# }
# ```
# result.data: {'medicine': 'loratadina', 'city_name': 'Campanário', 'uf': 'MG'}
# Pergunta: Qual o estoque de loratadina em Campanário, MG?
# Resultado extraído: city_name='Campanário' uf='MG' medicine='loratadina'
# ------------------------------------------------------------
# Resposta do LLM: ```json
# {
#   "medicine": "dipirona",
#   "city_name": "Goiânia",
#   "uf": "GO"
# }
# ```
# result.data: {'medicine': 'dipirona', 'city_name': 'Goiânia', 'uf': 'GO'}
# Pergunta: Tem dipirona em Goiânia, GO?
# Resultado extraído: city_name='Goiânia' uf='GO' medicine='dipirona'
# ------------------------------------------------------------
# Resposta do LLM: ```json
# {
#   "medicine": "ibuprofeno",
#   "city_name": "São Paulo",
#   "uf": "SP"
# }
# ```
# result.data: {'medicine': 'ibuprofeno', 'city_name': 'São Paulo', 'uf': 'SP'}
# ...

# %%
from src.agents.tools.extract_parameters import extract_parameters_tool

# %%
from src.agents.tools.extract_parameters import extract_parameters_tool
# Out:
# 2025-07-08 17:57:17.237 | INFO     | src.config:<module>:13 - PROJ_ROOT path is: C:\Ana\Pessoal\TCC\tcc_ufg_akcit_nlp
