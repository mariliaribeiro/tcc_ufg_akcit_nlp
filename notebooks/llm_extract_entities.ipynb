# %%
import sys
import os

# Adiciona o diretório raiz do projeto ao sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.agents.tools.extract_parameters import extract_parameters_from_question
# Out:
# 2025-07-09 12:44:52.678 | INFO     | src.config:<module>:13 - PROJ_ROOT path is: C:\Ana\Pessoal\TCC\tcc_ufg_akcit_nlp

# %%
perguntas = [
    "Qual o estoque de loratadina em Campanário, MG?",
]

for pergunta in perguntas:
    resultado = extract_parameters_from_question(pergunta)
    print(f'Pergunta: {pergunta}')
    print('Resultado extraído:', resultado)
    print('-' * 60)
# Out:
# Resposta do LLM: ```json
# {
#   "medicamento": "loratadina",
#   "nome_municipio": "Campanário",
#   "codigo_municipio": "",
#   "uf": "MG"
# }
# ```
# Conteúdo data: {'medicamento': 'loratadina', 'nome_municipio': 'Campanário', 'codigo_municipio': '', 'uf': 'MG'}
# Consulta no MongoDB: cidade='Campanário', uf='MG'
# Resultado: 311080
# Novo conteúdo data: {'medicamento': 'loratadina', 'nome_municipio': 'Campanário', 'codigo_municipio': '311080', 'uf': 'MG'}
# Pergunta: Qual o estoque de loratadina em Campanário, MG?
# Resultado extraído: nome_municipio='Campanário' codigo_municipio='311080' uf='MG' medicamento='loratadina'
# ------------------------------------------------------------
