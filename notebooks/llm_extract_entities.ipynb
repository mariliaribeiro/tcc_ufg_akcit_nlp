# %%
import sys
import os

# Adiciona o diretório raiz do projeto ao sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.agents.tools.extract_parameters import EntityExtractor
# Out:
# 2025-07-09 13:21:03.324 | INFO     | src.config:<module>:13 - PROJ_ROOT path is: C:\Ana\Pessoal\TCC\tcc_ufg_akcit_nlp

# %%
ee = EntityExtractor()

# %%
perguntas = [
    "Qual o estoque de loratadina em Campanário, MG?",
]

for pergunta in perguntas:
    resultado = ee.retriever(pergunta)
    print(f'Pergunta: {pergunta}')
    print('Resultado extraído:', resultado)
    print('-' * 60)
# Out:
# Consulta no MongoDB: cidade='Campanário', uf='MG'
# Resultado: 311080
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 6
#       1 perguntas = [
#       2     "Qual o estoque de loratadina em Campanário, MG?",
#       3 ]
#       5 for pergunta in perguntas:
# ----> 6     resultado = ee.retriever(pergunta)
#       7     print(f'Pergunta: {pergunta}')
#       8     print('Resultado extraído:', resultado)
#
# File C:\Ana\Pessoal\TCC\tcc_ufg_akcit_nlp\src\agents\tools\extract_parameters.py:97, in EntityExtractor.retriever(self, question)
#      88 human_prompt = HumanMessagePromptTemplate(
#      89     prompt=PromptTemplate(input_variables=["question"], template="{question}")
#      90 )
#      92 prompt_template = ChatPromptTemplate(
#      93     input_variables=["context", "question"],
#      94     messages=[system_prompt, human_prompt]
#      95 )
# ---> 97 context = self.get_context(question)
#      98 output_parser = StrOutputParser()
#      99 chain = prompt_template | self.llm | output_parser
#
# File C:\Ana\Pessoal\TCC\tcc_ufg_akcit_nlp\src\agents\tools\extract_parameters.py:71, in EntityExtractor.get_context(self, question)
#      66     print("Erro ao fazer parsing do JSON:", e)
#      67     structured_data = ExtractParametersOutput(
#      68         medicamento="", nome_municipio="", codigo_municipio="", uf=""
#      69     )
# ---> 71 context = CONTEXT.format(structured_data=structured_data)
#      72 print(f"\n\nContext:\n{context}")
#      73 return context
#
# KeyError: 'context'
